# %% [markdown]
# # vectormigrate Walkthrough
#
# This notebook documents the local benchmark and migration workflow using the sample JSONL assets.

# %%
from pathlib import Path
from vectormigrate.io import load_documents, load_query_cases

docs = load_documents(Path('examples/sample_documents.jsonl'))
queries = load_query_cases(Path('examples/sample_queries.jsonl'))
len(docs), len(queries)
